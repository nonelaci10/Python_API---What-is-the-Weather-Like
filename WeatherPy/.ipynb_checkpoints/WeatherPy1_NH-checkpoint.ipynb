# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "data_cities(1).csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %%
#Perform API Calls
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

cities_name = []
cloudiness = []
country_name = []
date = []
humidity1 = []
lat = []
lng = []
max_tem = []
wind_speed = []

weather_url = f"{url}appid={weather_api_key}&units={units}&q="
    

#def build_url(lat, lon):
    #part1 = "http://api.openweathermap.org/data/2.5/weather?lat=" + str(lat)
    #part2 = "&lon=" + str(lon)
    #part3 = "&count&appid=" + weather_api_key
    
    #return part1 + part2 + part3
    
count = 1

for city in cities:
    count = count + 1
    #if count >= 60:
    #    break
    response = requests.get(weather_url + city).json()
    #print(json.dumps(response, indent=4, sort_keys=True))
    if response['cod'] == '404' :
        print ("City " + city + " was not found")
    else:
        print("Processing record " + str(count) + " of set 1 " + "| " + response['name'])
        # Grab values from JSON and put them in dataframe
        lat.append(response['coord']['lat'])
        max_tem.append(response['main']['temp'])
        cities_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country_name.append(response['sys']['country'])
        date.append(response['dt'])
        humidity1.append(response['main']['humidity'])
        lng.append(response['coord']['lon'])
        wind_speed.append(response['wind']['speed'])

#print(weather_dict)
    #lats.append(response['coord']['lat']['lng'])
    #temp.append(response['main']['temp'])   

# Pretty Print the output of the JSON
#response = requests.get(weather_url + len(cities)).json()


#print(type(response_json))

#city = response_json['list'][0]['name']
#print(city)
# Out:
# Processing record 2 of set 1 | Severo-Kuril'sk
# Processing record 3 of set 1 | Chui
# City scottsburgh was not found
# Processing record 5 of set 1 | Saint Anthony
# Processing record 6 of set 1 | Mount Gambier
# City hongan was not found
# Processing record 8 of set 1 | Kahului
# Processing record 9 of set 1 | Gboko
# Processing record 10 of set 1 | Bluff
# City taolanaro was not found
# Processing record 12 of set 1 | Port Alfred
# Processing record 13 of set 1 | Bredasdorp
# Processing record 14 of set 1 | Tuktoyaktuk
# City nizhneyansk was not found
# City meyungs was not found
# Processing record 17 of set 1 | Birjand
# Processing record 18 of set 1 | Rikitea
# Processing record 19 of set 1 | Kruisfontein
# Processing record 20 of set 1 | East London
# Processing record 21 of set 1 | Bathsheba
# Processing record 22 of set 1 | Provideniya
# Processing record 23 of set 1 | Fortuna
# Processing record 24 of set 1 | Puerto Ayora
# Processing record 25 of set 1 | Yellowknife
# ...

# %%
#Convert Raw Data to DataFrame
#Export the city data into a .csv.
#Display the DataFrame
weather_dict = {
    "City": cities_name,
    "Lat": lat,
    "Max Temp": max_tem,
    "Cloudiness": cloudiness,
    "Country" : country_name,
    "Date" : date,
    "Humidity" : humidity1,
    "Lng": lng,
    "Wind Speed" : wind_speed
}
weather_df = pd.DataFrame(weather_dict)

weather_df
# Out:
#                  City    Lat  Max Temp  Cloudiness Country        Date  \
# 0     Severo-Kuril'sk  50.68     -6.50         100      RU  1583346858
# 1                Chui -33.70     26.91          15      UY  1583346858
# 2       Saint Anthony  45.02      3.05          90      US  1583346859
# 3       Mount Gambier -37.83     15.00          90      AU  1583346859
# 4             Kahului  20.89     21.53          20      US  1583346646
# ..                ...    ...       ...         ...     ...         ...
# 545             Hobyo   5.35     24.97           0      SO  1583346960
# 546      Três de Maio -27.77     31.90           0      BR  1583346776
# 547       Kangaatsiaq  68.31    -22.91          17      GL  1583346960
# 548          Fukuechō  32.69      5.00          20      JP  1583346961
# 549  Imeni Babushkina  59.76     -6.96           0      RU  1583346961
#
#      Humidity     Lng  Wind Speed
# 0          94  156.12        3.01
# 1          50  -53.46        5.12
# ...

# %%
weather_df.to_csv(output_data_file )

# %%
#Plotting the Data
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.

# %%
#Latitude vs. Temperature Plot

# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatVsTemp.png")

# Show plot
plt.show()

# %%
print(f" This scatter graph displays the relationship of a cities latitude and temperature.")
# Out:
#  This scatter graph displays the relationship of a cities latitude and temperature.

# %%
#Latitude vs. Humidity Plot

# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatVsHumidity.png")

# Show plot
plt.show()

# %%
print(f"This plot displays the realtionship of Humidity and Latitude, more humidity with bigger latitude.")
# Out:
# This plot displays the realtionship of Humidity and Latitude, more humidity with bigger latitude.

# %%
#### Latitude vs. Cloudiness Plot

# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatVsCloudiness.png")

# Show plot
plt.show()

# %%
print("This plot display is a bit more scattered than the previous ones, since cloudiness can vary on locations and terrains.")
# Out:
# This plot display is a bit more scattered than the previous ones, since cloudiness can vary on locations and terrains.

# %%
#### Latitude vs. Wind Speed Plot
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatVsWindSpeed.png")

# Show plot
plt.show()

# %%
print("The Wind Speed realtionship with the Latitude, varies on locations and their terrains, which allows wind formations.")
# Out:
# The Wind Speed realtionship with the Latitude, varies on locations and their terrains, which allows wind formations.

# %%
## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %%
####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
